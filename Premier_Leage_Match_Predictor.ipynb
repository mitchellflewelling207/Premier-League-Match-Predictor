# %%
import pandas as pd

# %%
# Load the data
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1  8/15/2021  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2  8/21/2021  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3  8/28/2021  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4  9/11/2021  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6  9/18/2021  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  match report  notes  sh  sot  dist fk pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18    4  16.9  1  0     0
# 2    Norwich City  ...  Match Report    NaN  16    4  17.3  1  0     0
# 3         Arsenal  ...  Match Report    NaN  25   10  14.3  0  0     0
# 4  Leicester City  ...  Match Report    NaN  25    8  14.0  0  0     0
# 6     Southampton  ...  Match Report    NaN  16    1  15.7  1  0     0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %%
#38 games per season, 20 teams per league, 2 seasons worth of data
#should have more matches than this.
38 * 20 * 2
# Out:
# 1520

# %%
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1    9/12/2020  17:30  Premier League   Matchweek 1  Sat  Home      W   4   3
# 2    9/20/2020  16:30  Premier League   Matchweek 2  Sun  Away      W   2   0
# 4    9/28/2020  20:00  Premier League   Matchweek 3  Mon  Home      W   3   1
# 6    10/4/2020  19:15  Premier League   Matchweek 4  Sun  Away      L   2   7
# 7   10/17/2020  12:30  Premier League   Matchweek 5  Sat  Away      D   2   2
# 9   10/24/2020  20:00  Premier League   Matchweek 6  Sat  Home      W   2   1
# 11  10/31/2020  17:30  Premier League   Matchweek 7  Sat  Home      W   2   1
# 13   11/8/2020  16:30  Premier League   Matchweek 8  Sun  Away      D   1   1
# 14  11/22/2020  19:15  Premier League   Matchweek 9  Sun  Home      W   3   0
# 16  11/28/2020  12:30  Premier League  Matchweek 10  Sat  Away      D   1   1
# 18   12/6/2020  19:15  Premier League  Matchweek 11  Sun  Home      W   4   0
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
#Clean data
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss              int64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh                int64
# sot               int64
# dist            float64
# fk                int64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
#convert existing column to datetime
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                     int64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                       int64
# sot                      int64
# dist                   float64
# fk                       int64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
#Conversion
#String --> Categorical --> Numeric
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
#each team now has a numerical value
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#just get hour variable for easier computations
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype(int)

# %%
#get day of the week, associate it with a #
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#turn W into 1, L into 0
matches["target"] = (matches["result"] == "W").astype(int)

# %%
#ML Model - Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
#call the class, n is # of trees in the forest
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#split training/testing data
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
#train a random forest model, target is the result
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
#get accuracy of model
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6123188405797102

# %%
#combine actual and predicted values
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
#improve accuracy of the model with more predictors
grouped_matches = matches.groupby("team")

# %%
#all matches played by one team (Man City)
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W   2   0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L   1   2
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W   4   3
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L   2   3
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   5   0
#
# ...

# %%
#function to predict rolling averages
# Ex: if a team lost the prev 3 games, they are more likely to lose the next game
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats  
    #remove NaN values
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
#rolling avg columns
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
#averages for Man City games
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D   1   1
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L   0   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D   0   0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W   2   0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D   2   2
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W   3   0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W   5   1
#
# ...

# %%
#
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\mitch\AppData\Local\Temp\ipykernel_58728\428728851.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
#drop unnecessary index
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W   1   0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L   2   3
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W   2   1
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L   0   1
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L   0   1
#
# ...

# %%
#get unique indexes
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W   1
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L   2
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W   2
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L   0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L   0
#
# ...

# %%
#retrain model with new predictors
def make_predicitions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']

    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)

    return combined, precision

# %%
#make predictions
combined, precision = make_predicitions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.625

# %%
#combine rolling averages with original data
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team       opponent  \
# 55         0           0 2022-01-23                  Arsenal        Burnley
# 56         1           0 2022-02-10                  Arsenal         Wolves
# 57         1           0 2022-02-19                  Arsenal      Brentford
# 58         1           1 2022-02-24                  Arsenal         Wolves
# 59         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1312       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0           0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# ...

# %%
#keep team and opponent names consistent
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Bright and Hove Albion": "Brighton",
    "Manchester United" : "Manchester Utd",
    "Newcastle United" : "Newcastle",
    "Tottenham Hotspur" : "Tottennham",
    "West Ham United" : "West Ham",
    "Wolverhampton Wanderers" : "Wolves"
}

mapping = MissingDict(map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  prediction       date                     team       opponent  \
# 55         0           0 2022-01-23                  Arsenal        Burnley
# 56         1           0 2022-02-10                  Arsenal         Wolves
# 57         1           0 2022-02-19                  Arsenal      Brentford
# 58         1           1 2022-02-24                  Arsenal         Wolves
# 59         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1312       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0           0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 55        D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"]) ##merge on date and team

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             0 2022-01-23                  Arsenal
# 1           1             0 2022-02-10                  Arsenal
# 2           1             0 2022-02-19                  Arsenal
# 3           1             1 2022-02-24                  Arsenal
# 4           1             1 2022-03-06                  Arsenal
# ..        ...           ...        ...                      ...
# 212         1             0 2022-03-13  Wolverhampton Wanderers
# 213         0             0 2022-03-18  Wolverhampton Wanderers
# 214         1             0 2022-04-02  Wolverhampton Wanderers
# 215         0             0 2022-04-08  Wolverhampton Wanderers
# 216         0             0 2022-04-24  Wolverhampton Wanderers
#
#         opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0          Burnley        D    Arsenal         0             0
# 1           Wolves        W    Arsenal         0             0
# ...

# %%
## get the actual results of the games
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    20
# 0    10
# Name: count, dtype: int64

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             0 2022-01-23                  Arsenal
# 1           1             0 2022-02-10                  Arsenal
# 2           1             0 2022-02-19                  Arsenal
# 3           1             1 2022-02-24                  Arsenal
# 4           1             1 2022-03-06                  Arsenal
# ..        ...           ...        ...                      ...
# 212         1             0 2022-03-13  Wolverhampton Wanderers
# 213         0             0 2022-03-18  Wolverhampton Wanderers
# 214         1             0 2022-04-02  Wolverhampton Wanderers
# 215         0             0 2022-04-08  Wolverhampton Wanderers
# 216         0             0 2022-04-24  Wolverhampton Wanderers
#
#         opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0          Burnley        D    Arsenal         0             0
# 1           Wolves        W    Arsenal         0             0
# ...
